# %% [markdown]
# <a href="https://colab.research.google.com/github/cu2mauro/NN_matlab_bubble/blob/colabwork/ColabCNNtry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convolutional Neural Network to classify MATLAB bubble results
#
# The problem is to understand how the result $y$ of the 2D integration of a nonlinear function $f$ depends on the boundary of the integration domain $\Omega$, described as a 2D Bspline-curve $\partial\Omega$:
# $$y[X]=\int_{\Omega[X]} f(z,\rho)dzd\rho.$$
# The input $X$ of the NN is the vector of coefficients of the said curve, while the output is the result of the integral. Many integration with random (but plausible) coefficients are performed in MATLAB and their results are used as a training set.
#
# To build, train and test the CNN we use keras with the tensorflow backend.
# Below we import the necessary modules.

# %%
import numpy as np #numerical
import pandas as pd #data analysis
from sklearn.model_selection import train_test_split
from skimage.transform import resize
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
import scipy.io as sio
from scipy import interpolate
from scipy.interpolate import BSpline, make_interp_spline
import sys
# %matplotlib inline
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras import backend as K
from os.path import dirname, join as pjoin

# %% [markdown]
# Load dataset: vectors of control points in X, actions in y.

# %%
from google.colab import drive
drive.mount('/content/drive');
# Out:
# Mounted at /content/drive

# %%
mat = sio.loadmat('/content/drive/MyDrive/NN/NNtotNew')
data = mat['results']
X = np.reshape(np.vstack(data[:,0][:]),(len(data),12))
y = np.vstack(data[:,3][:])
X = np.expand_dims(np.reshape(np.c_[np.zeros(len(y)),X,np.zeros(len(y))],(len(y),2,7)), axis=3) # add zeros for first X and last Y coordinates, reshape

print(X.shape,y.shape)
# Out:
# (4917, 2, 7, 1) (4917, 1)

# %% [markdown]
# Divide dataset into training (80%), validation (10%) and test set (10%)

# %%
Ntot = len(X)
tot_ind = np.arange(Ntot)
random.shuffle(tot_ind)
val_ind = tot_ind[int(Ntot*0.8):int(Ntot*0.9)]
train_ind = tot_ind[0:int(Ntot*0.8)]
test_ind = tot_ind[int(Ntot*0.9):]
X_train = X[train_ind]
y_train = y[train_ind]
X_val = X[val_ind]
y_val = y[val_ind]
X_test = X[test_ind]
y_test = y[test_ind]

print(X_train.shape)
# Out:
# (3933, 2, 7, 1)

# %% [markdown]
# What is our data: show border $\partial\Omega$, spline-curve control points $X$, and corresponding action $y$:

# %%
t = np.random.randint(len(X))
plt.scatter(np.transpose(data[t,1]['Points'][0][0])[0],np.transpose(data[t,1]['Points'][0][0])[1])
plt.scatter(X[t][0],X[t][1])
plt.plot(X[t][0],X[t][1],'r')
S = 'y='+str(y[t][0])
plt.title(S);
plt.show()

# %% [markdown]
# The choice of the CNN architecture was motivated by the importance of the spatial information of the input (control point `X[i,j]` cares about control points `X[i±1,j±1]`).
#
# We now build the CNN, compile and train/validate it:

# %%
model_cnn = Sequential()
model_cnn.add(Conv2D(4, (2, 2), activation='relu', input_shape=(2, 7, 1)))
model_cnn.add(BatchNormalization())
model_cnn.add(Flatten())
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(128, activation='relu'))
model_cnn.add(BatchNormalization())
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(1, activation='linear')) #linear? for regression

# %%
model_cnn = Sequential()
model_cnn.add(Conv2D(8, (2, 2), activation='relu', input_shape=(2, 7, 1), padding='same', kernel_regularizer=keras.regularizers.l2(0.01)))
model_cnn.add(BatchNormalization())
model_cnn.add(Conv2D(16, (2, 2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)))
model_cnn.add(BatchNormalization())
model_cnn.add(Flatten())
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)))
model_cnn.add(BatchNormalization())
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01)))
model_cnn.add(BatchNormalization())
model_cnn.add(Dense(1, activation='linear')) #linear for regression

# %%
model=model_cnn
model.summary()

def lr_schedule(epoch):
    lr = 1e2
    if epoch > 50:
        lr *= 0.1
    if epoch > 100:
        lr *= 0.1
    if epoch > 200:
        lr *= 0.1
    return lr

lr_scheduler = keras.callbacks.LearningRateScheduler(lr_schedule)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss',
                                               patience=50,
                                               restore_best_weights=True)

model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adam(learning_rate=lr_schedule(0)),
              metrics=['mean_absolute_error'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 1, 6, 4)           20
#
#  batch_normalization_20 (Ba  (None, 1, 6, 4)           16
#  tchNormalization)
#
#  flatten_5 (Flatten)         (None, 24)                0
#
#  dropout_10 (Dropout)        (None, 24)                0
#
#  dense_15 (Dense)            (None, 128)               3200
#
#  batch_normalization_21 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 3877 (15.14 KB)
# Trainable params: 3613 (14.11 KB)
# Non-trainable params: 264 (1.03 KB)
# _________________________________________________________________

# %%
nn_history1 = model.fit(X_train, y_train,
                        batch_size=128,
                        epochs=500,
                        verbose=1,
                        validation_data=(X_val, y_val),
                        callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/500
# 31/31 [==============================] - 0s 10ms/step - loss: 1204342.3750 - mean_absolute_error: 369.4410 - val_loss: 227803.3125 - val_mean_absolute_error: 237.4753 - lr: 100.0000
# Epoch 2/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1289632.3750 - mean_absolute_error: 456.1364 - val_loss: 314215.2812 - val_mean_absolute_error: 357.1190 - lr: 100.0000
# Epoch 3/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1168195.6250 - mean_absolute_error: 360.7271 - val_loss: 200038.6250 - val_mean_absolute_error: 171.4613 - lr: 100.0000
# Epoch 4/500
# 31/31 [==============================] - 0s 7ms/step - loss: 1197050.7500 - mean_absolute_error: 361.5850 - val_loss: 215828.6094 - val_mean_absolute_error: 225.6460 - lr: 100.0000
# Epoch 5/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1140174.2500 - mean_absolute_error: 307.2146 - val_loss: 202506.1094 - val_mean_absolute_error: 164.6185 - lr: 100.0000
# Epoch 6/500
# 31/31 [==============================] - 0s 7ms/step - loss: 1195937.8750 - mean_absolute_error: 371.4665 - val_loss: 230076.3594 - val_mean_absolute_error: 207.5751 - lr: 100.0000
# Epoch 7/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1202751.1250 - mean_absolute_error: 364.9419 - val_loss: 215179.7031 - val_mean_absolute_error: 173.0215 - lr: 100.0000
# Epoch 8/500
# 31/31 [==============================] - 0s 9ms/step - loss: 1122663.1250 - mean_absolute_error: 270.6320 - val_loss: 207507.7812 - val_mean_absolute_error: 205.9453 - lr: 100.0000
# Epoch 9/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1126097.1250 - mean_absolute_error: 303.6101 - val_loss: 190962.8125 - val_mean_absolute_error: 108.9165 - lr: 100.0000
# Epoch 10/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1166252.5000 - mean_absolute_error: 329.0800 - val_loss: 202066.8438 - val_mean_absolute_error: 127.1281 - lr: 100.0000
# Epoch 11/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1176337.6250 - mean_absolute_error: 301.0805 - val_loss: 192761.8750 - val_mean_absolute_error: 102.9543 - lr: 100.0000
# Epoch 12/500
# 31/31 [==============================] - 0s 7ms/step - loss: 1104041.8750 - mean_absolute_error: 267.2257 - val_loss: 193351.7656 - val_mean_absolute_error: 92.6260 - lr: 100.0000
# Epoch 13/500
# 31/31 [==============================] - 0s 10ms/step - loss: 1107560.6250 - mean_absolute_error: 261.7335 - val_loss: 197193.1875 - val_mean_absolute_error: 133.2653 - lr: 100.0000
# Epoch 14/500
# 31/31 [==============================] - 0s 8ms/step - loss: 1235275.5000 - mean_absolute_error: 403.1738 - val_loss: 213554.3750 - val_mean_absolute_error: 165.7080 - lr: 100.0000
# Epoch 15/500
# 31/31 [==============================] - 0s 7ms/step - loss: 1156275.1250 - mean_absolute_error: 317.7880 - val_loss: 207790.6094 - val_mean_absolute_error: 198.2155 - lr: 100.0000
# Epoch 16/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1096625.1250 - mean_absolute_error: 253.9639 - val_loss: 212681.2500 - val_mean_absolute_error: 217.4227 - lr: 100.0000
# Epoch 17/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1096282.6250 - mean_absolute_error: 255.2749 - val_loss: 239462.2812 - val_mean_absolute_error: 233.3173 - lr: 100.0000
# Epoch 18/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1139695.2500 - mean_absolute_error: 293.5885 - val_loss: 231373.8438 - val_mean_absolute_error: 272.3830 - lr: 100.0000
# Epoch 19/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1134248.2500 - mean_absolute_error: 278.1232 - val_loss: 195202.7969 - val_mean_absolute_error: 138.8280 - lr: 100.0000
# Epoch 20/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1150037.2500 - mean_absolute_error: 295.1652 - val_loss: 200137.9062 - val_mean_absolute_error: 168.9286 - lr: 100.0000
# Epoch 21/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1183084.6250 - mean_absolute_error: 318.2200 - val_loss: 193194.8594 - val_mean_absolute_error: 111.9302 - lr: 100.0000
# Epoch 22/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1118684.1250 - mean_absolute_error: 272.0726 - val_loss: 194047.1250 - val_mean_absolute_error: 132.7958 - lr: 100.0000
# Epoch 23/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1095234.6250 - mean_absolute_error: 249.0348 - val_loss: 198717.9531 - val_mean_absolute_error: 169.6503 - lr: 100.0000
# Epoch 24/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1105392.8750 - mean_absolute_error: 264.3724 - val_loss: 192354.7969 - val_mean_absolute_error: 99.1561 - lr: 100.0000
# Epoch 25/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1085871.7500 - mean_absolute_error: 232.7106 - val_loss: 204854.7031 - val_mean_absolute_error: 142.1844 - lr: 100.0000
# Epoch 26/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1083332.5000 - mean_absolute_error: 230.7373 - val_loss: 191676.4062 - val_mean_absolute_error: 111.0227 - lr: 100.0000
# Epoch 27/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1089620.6250 - mean_absolute_error: 234.7992 - val_loss: 193732.8594 - val_mean_absolute_error: 89.3314 - lr: 100.0000
# Epoch 28/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1079881.5000 - mean_absolute_error: 214.6840 - val_loss: 194652.1562 - val_mean_absolute_error: 128.3974 - lr: 100.0000
# Epoch 29/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1072495.7500 - mean_absolute_error: 223.1225 - val_loss: 192102.2500 - val_mean_absolute_error: 115.6095 - lr: 100.0000
# Epoch 30/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1076112.7500 - mean_absolute_error: 206.8852 - val_loss: 199144.0938 - val_mean_absolute_error: 164.2355 - lr: 100.0000
# Epoch 31/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1073721.2500 - mean_absolute_error: 215.0977 - val_loss: 192687.6719 - val_mean_absolute_error: 94.2975 - lr: 100.0000
# Epoch 32/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1079928.6250 - mean_absolute_error: 228.6687 - val_loss: 196813.7812 - val_mean_absolute_error: 143.4251 - lr: 100.0000
# Epoch 33/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1104458.5000 - mean_absolute_error: 240.1602 - val_loss: 195465.8906 - val_mean_absolute_error: 105.2909 - lr: 100.0000
# Epoch 34/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1165044.8750 - mean_absolute_error: 317.7424 - val_loss: 207858.9844 - val_mean_absolute_error: 201.4242 - lr: 100.0000
# Epoch 35/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1100617.2500 - mean_absolute_error: 239.0028 - val_loss: 232959.6406 - val_mean_absolute_error: 274.9808 - lr: 100.0000
# Epoch 36/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1129354.0000 - mean_absolute_error: 271.6127 - val_loss: 193993.6406 - val_mean_absolute_error: 84.5910 - lr: 100.0000
# Epoch 37/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1089883.2500 - mean_absolute_error: 229.0665 - val_loss: 193549.1719 - val_mean_absolute_error: 94.7435 - lr: 100.0000
# Epoch 38/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1087481.2500 - mean_absolute_error: 227.8448 - val_loss: 193952.4062 - val_mean_absolute_error: 109.4555 - lr: 100.0000
# Epoch 39/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1107985.7500 - mean_absolute_error: 239.8906 - val_loss: 193268.5781 - val_mean_absolute_error: 104.8581 - lr: 100.0000
# Epoch 40/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1100358.8750 - mean_absolute_error: 236.3088 - val_loss: 192686.5781 - val_mean_absolute_error: 91.1745 - lr: 100.0000
# Epoch 41/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1095845.8750 - mean_absolute_error: 230.4725 - val_loss: 229531.3750 - val_mean_absolute_error: 269.4726 - lr: 100.0000
# Epoch 42/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1094146.7500 - mean_absolute_error: 248.8631 - val_loss: 194272.9375 - val_mean_absolute_error: 83.5133 - lr: 100.0000
# Epoch 43/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1092682.6250 - mean_absolute_error: 254.7659 - val_loss: 193397.0156 - val_mean_absolute_error: 101.5904 - lr: 100.0000
# Epoch 44/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1080469.7500 - mean_absolute_error: 212.1105 - val_loss: 192344.9531 - val_mean_absolute_error: 99.7098 - lr: 100.0000
# Epoch 45/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1078331.7500 - mean_absolute_error: 197.3901 - val_loss: 193607.7188 - val_mean_absolute_error: 107.4167 - lr: 100.0000
# Epoch 46/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1106179.6250 - mean_absolute_error: 247.9209 - val_loss: 209173.7656 - val_mean_absolute_error: 206.6625 - lr: 100.0000
# Epoch 47/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1082184.8750 - mean_absolute_error: 222.3260 - val_loss: 195204.9375 - val_mean_absolute_error: 125.3072 - lr: 100.0000
# Epoch 48/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1070674.1250 - mean_absolute_error: 193.8255 - val_loss: 192615.5469 - val_mean_absolute_error: 114.7091 - lr: 100.0000
# Epoch 49/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1090735.6250 - mean_absolute_error: 243.0248 - val_loss: 192711.3125 - val_mean_absolute_error: 113.8052 - lr: 100.0000
# Epoch 50/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1075523.0000 - mean_absolute_error: 195.9877 - val_loss: 193710.3281 - val_mean_absolute_error: 121.5695 - lr: 100.0000
# Epoch 51/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1074412.7500 - mean_absolute_error: 213.2622 - val_loss: 194212.3125 - val_mean_absolute_error: 123.4356 - lr: 100.0000
# Epoch 52/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1067975.2500 - mean_absolute_error: 184.6889 - val_loss: 195423.1719 - val_mean_absolute_error: 135.0617 - lr: 10.0000
# Epoch 53/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1065527.2500 - mean_absolute_error: 188.8344 - val_loss: 192926.6875 - val_mean_absolute_error: 98.4652 - lr: 10.0000
# Epoch 54/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1066075.1250 - mean_absolute_error: 172.6095 - val_loss: 192891.8438 - val_mean_absolute_error: 110.3065 - lr: 10.0000
# Epoch 55/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1062966.7500 - mean_absolute_error: 173.0443 - val_loss: 194939.2969 - val_mean_absolute_error: 136.5251 - lr: 10.0000
# Epoch 56/500
# 31/31 [==============================] - 0s 5ms/step - loss: 1066052.1250 - mean_absolute_error: 163.2729 - val_loss: 193996.7500 - val_mean_absolute_error: 125.3997 - lr: 10.0000
# Epoch 57/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1066302.0000 - mean_absolute_error: 173.0617 - val_loss: 194355.1406 - val_mean_absolute_error: 129.3394 - lr: 10.0000
# Epoch 58/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1065611.0000 - mean_absolute_error: 181.6549 - val_loss: 193009.7500 - val_mean_absolute_error: 109.6678 - lr: 10.0000
# Epoch 59/500
# 31/31 [==============================] - 0s 6ms/step - loss: 1064201.3750 - mean_absolute_error: 170.5258 - val_loss: 195659.3906 - val_mean_absolute_error: 140.3901 - lr: 10.0000

# %%
plt.plot(nn_history1.history['loss'])
plt.plot(nn_history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.show()

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
# Out:
# Test score: 0.25534719228744507

# %% [markdown]
# ---

# %%
#model=keras.models.load_model('/content/drive/MyDrive/NN/model1.keras')

# %%
plt.plot(nn_history.history['loss'])
plt.plot(nn_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')
plt.show()

# %% [markdown]
# Test with input from MATLAB

# %%
Xn=np.array([[0.    , 0.0518,    0.1000,    0.1414,    0.1732,   0.1932,    0.2000],
 [    0.2000,    0.1932,    0.1732,    0.1414,    0.1000,    0.0518, 0.]])
Xn=np.expand_dims(Xn, axis=2)
Xn=np.expand_dims(Xn, axis=0)

# %%
print('The predicted action is y=',np.arctanh(model.predict(Xn,verbose=0))[0][0])
# Out:
# The predicted action is y= 0.2959942

# %%
#model.save('/content/drive/MyDrive/NN/modelN.keras')
